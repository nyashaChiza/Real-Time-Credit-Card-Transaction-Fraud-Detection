# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt, rcParams
import seaborn as sns
rcParams['figure.figsize'] = 11,10

link = '../Datasets/unPCA_data.csv'

# %%
df = pd.read_csv(link)

# %%
df.columns = colu

# %%
columns = ['Transaction_id', 'Balance', 'Amount', 'Cvv', 'Number_of_items', 'Bank_id', 'Mechant_Code', 'PC7', 'Account_Number',
       'Card_Number', 'Time', 'Asv', 'PC12', 'PC13', 'PC14', 'PC15', 'PC16', 'PC17',
       'PC18', 'Class']

# %%
df.head()
# Out:
#    Transaction_id   Balance    Amount       Cvv  Number_of_items   Bank_id  \
# 0               0 -5.221450 -0.282993 -2.325171         0.336731  1.175352
# 1               1 -5.194667 -0.137556 -0.823326        -0.619209 -0.265349
# 2               2 -5.887422  1.442774  2.647117         0.942626 -0.465722
# 3               3 -5.201025 -1.167545 -0.734201        -0.427930 -0.687691
# 4               4 -4.821635  1.352308  2.583916         0.003548  0.546032
#
#    Mechant_Code       PC7  Account_Number  Card_Number      Time       Asv  \
# 0      0.627345  1.651493        0.769026    -0.408388 -0.153905  0.464682
# 1     -1.002875  0.107806        0.806539     1.711428  0.050859  0.002961
# 2     -0.200738  0.197844        0.005203    -0.124002 -0.174634 -0.666763
# 3      0.637109 -0.607841        0.015695    -0.357413 -1.062468 -0.965042
# 4     -1.585428  1.057875        1.447790     0.827919  0.116987 -0.203904
#
# ...
